# %% [markdown]
# <a href="https://colab.research.google.com/github/Hprasad2003/python-program/blob/main/python_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="Hari"
salary=100000
print("my name is:,Hari")
print("my salary is:,100000")
# Out:
# my name is:,Hari
# my salary is:,100000

# %%
name="Smiley"
age=23
district="andhrapradesh"
print("my name is:",name)
print("my age is:",age)
print("my district is:",district)
print()
print("my name is:",type(name))
print("my age is:",type(age))
print("my district is:",type(district))
# Out:
# my name is: Smiley
# my age is: 23
# my district is: andhrapradesh
#
# my name is: <class 'str'>
# my age is: <class 'int'>
# my district is: <class 'str'>

# %% [markdown]
# data type simple program

# %%
name="swetha"
heigth=5.9
print("my name is:","swetha")
print("my heigth is:",5.9)
print()
print("my name is:",type(name))
print("my heigth is:",type(heigth))
# Out:
# my name is: swetha
# my heigth is: 5.9
#
# my name is: <class 'str'>
# my heigth is: <class 'float'>

# %%
student_id=3
salary=25000
print("my student_id is:",3)
print("my salary is:",25000)
print()
print("my name is:",type(name))
print("my salary is:",type(salary))
# Out:
# my student_id is: 3
# my salary is: 25000
#
# my name is: <class 'str'>
# my salary is: <class 'int'>

# %%
fruits=["bannna","apple","oreng","greaps"]
#print(fruits):

# %%
a=5+6j
print(a)
print(type(a))
# Out:
# (5+6j)
# <class 'complex'>

# %%
a=(9,16,7,2)
print(a)
print(type(a))
# Out:
# (9, 16, 7, 2)
# <class 'tuple'>

# %%
a=12345
print(a)
print(type(a))
# Out:
# 12345
# <class 'int'>

# %%
a="hari"
print(a)
print(type(a))
# Out:
# hari
# <class 'str'>

# %%
a=[3,3,"python",3.13]
print(a)
print(type(a))
# Out:
# [3, 3, 'python', 3.13]
# <class 'list'>

# %% [markdown]
# TRUE OR FALSE PROGRAM

# %%
a=True
b=False
print(a)
print(b)
print(type(a))
print(type(b))
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# none program

# %%
a=None
print(a)
print(type(a))
# Out:
# None
# <class 'NoneType'>

# %% [markdown]
# MIXED PROGRAM

# %%
NAME=("LADDU")
HALLTICKETNUMBER=(123456789)
DORNUMBR=("YESH",3.13)
HEADCOUNT=(3,7,6,4)
ROLLNUMBER=("12345")
PRINT(NAME)
PRINT(HALLTICKETNUMBER)
PRINT(DORNUMBR)
PRINT(HEADCOUNT)
PRINT(ROLLNUMBER)
PRINT()
PRINT("MY NAME IS:",(TYPE("name"))
PRINT("MY HALLTICKETNUMBR IS:",(TYPE(123456789))
PRINT("MY DOR NUMBR IS:",(TYPE("YESH",3.13))
PRINT("MY HEAD COUNT IS:",(TYPE(3,7,5,6,4))
PRINT("MY ROLL NUMBR IS:",(TYPE(12345))
# Out:
#   File "/tmp/ipython-input-2468744166.py", line 12
#     PRINT("MY NAME IS:",(TYPE("name"))
#                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# Arithmetic operators program

# %%
a=15
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# 20
# 10
# 75
# 3.0
# 0
# 3
# 759375

# %%
a=15
b=5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**b)
print(a%b)
print(a//b)
# Out:
# 20
# 10
# 75
# 3.0
# 759375
# 0
# 3

# %% [markdown]
# asignment operator

# %%
a=13
+=7
print(a)
# Out:
# 13
# 20

# %% [markdown]
# Unary operator

# %%
a=10
print(a)

a=-10
print(a)
# Out:
# 10
# -10

# %% [markdown]
# Relational operators

# %%
a=13
b=7
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# True
# False
# True
# False
# False
# True

# %% [markdown]
# Logical Oprator

# %%
a=True
b=False
print(a and a)
print(a or b)
print(not a)
# Out:
# True
# True
# False

# %% [markdown]
# Membership Operator

# %%
a=[10,20,30]
print(15 in a)
print(10 in a)
print(30 in a)
# Out:
# False
# True
# True

# %% [markdown]
# input and output

# %%
name=input("enter your name:")
age=input("enter your age:")
print("you entered name:",name)
print("you entered age:",age)
# Out:
# enter your name:prasad
# enter your age:23
# you entered name: prasad
# you entered age: 23

# %% [markdown]
# converting the str to int

# %%
x=input("enter the first number:")
print(value x)
print(type(x))
y=input("enter the second number:")
print("int value y)
print(type(y))
# Out:
#   File "/tmp/ipython-input-3108976997.py", line 2
#     print(value x)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
x=100
y=200
print("x==y value is:",(x==y))
  if x==y:
  print("if block statement executed")
# Out:
#   File "/tmp/ipython-input-2808197809.py", line 4
#     if x==y:
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# single quotes

# %%
name ='prasad'
print(name)
print(type(name))
# Out:
# prasad
# <class 'str'>

# %% [markdown]
# double quotes

# %%
name ="prasad"
print(name)
print(type(name))
# Out:
# prasad
# <class 'str'>

# %% [markdown]
# single triple quotes

# %%
name ='''prasad'''
print(name)
print(type(name))
# Out:
# prasad
# <class 'str'>

# %% [markdown]
# double triple quotes

# %%
ame ="""prasad"""
print(name)
print(type(name))
# Out:
# prasad
# <class 'str'>

# %% [markdown]
# with single quotes or double quotes or triple single or double triple quotes

# %%
name1 ='prasad'
name2="hemanth"
name3='''hema'''
name4="""santhi"""
print(name1,"name is created by single quotes")
print(name2,"name is created by double quotes")
print(name3,"name is created by triple single quotes")
print(name4,"name is created by triple double quotes")
# Out:
# prasad name is created by single quotes
# hemanth name is created by double quotes
# hema name is created by triple single quotes
# santhi name is created by triple double quotes

# %% [markdown]
# single triple quotes and triple double qoutes

# %%
loc_1= '''IT company in
         hyderabad wipro'''

loc_2="""softwar company wipro
           hyderabad
           with blue color"""
print(loc_1)
print(loc_2)
# Out:
# IT company in
#          hyderabad wipro
# softwar company wipro
#            hyderabad
#            with blue color

# %% [markdown]
# zero to start

# %%
col="orange blue"
print(col[0])
print(col[1])
print(col[2])
print(col[3])
print(col[4])
print(col[5])
# Out:
# o
# r
# a
# n
# g
# e

# %% [markdown]
# string by using slicing

# %%
col="orange blue"
print(col[0])
print(col[7])
# Out:
# o
# b

# %% [markdown]
# using for loop

# %%
movi="chirutha ega"

for value in movi:
 print(value)
# Out:
# c
# h
# i
# r
# u
# t
# h
# a
#
# e
# g
# a

# %% [markdown]
# additon operator(+)

# %%
a="bag1"
b="bag2"
print(a+b)
# Out:
# bag1bag2

# %% [markdown]
# multiplication(*)operator

# %%
a="bottle"
print(a*4)
# Out:
# bottlebottlebottlebottle

# %% [markdown]
# string by using length() function

# %%
name="hariprasad"
print(len(name))
# Out:
# 10
